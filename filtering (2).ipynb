# %%
import numpy as np
import pandas as pd
d=pd.read_csv('C:\\Users\\GK\OneDrive\\Desktop\\insurance.csv')
d
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female    27.9         0    yes  southwest    16884.924
# 1      18    male   33.77         1     no  southeast    1725.5523
# 2      28    male      33         3     no  southeast     4449.462
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male   28.88         0     no  northwest    3866.8552
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male   30.97         3     no  northwest   10600.5483
# 1334   18  female   31.92         0     no  northeast    2205.9808
# 1335   18  female   36.85         0     no  southeast    1629.8335
# 1336   21  female    25.8         0     no  southwest     2007.945
# 1337   61  female   29.07         0     na  northwest   29141.3603
#
# [1338 rows x 7 columns]

# %%
print(d['bmi'].fillna(method='ffill'))
# Out:
# 0         27.9
# 1        33.77
# 2           33
# 3       22.705
# 4        28.88
#          ...
# 1333     30.97
# 1334     31.92
# 1335     36.85
# 1336      25.8
# 1337     29.07
# Name: bmi, Length: 1338, dtype: object

# %%
d.dropna(axis=0)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female    27.9         0    yes  southwest    16884.924
# 1      18    male   33.77         1     no  southeast    1725.5523
# 2      28    male      33         3     no  southeast     4449.462
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male   28.88         0     no  northwest    3866.8552
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male   30.97         3     no  northwest   10600.5483
# 1334   18  female   31.92         0     no  northeast    2205.9808
# 1335   18  female   36.85         0     no  southeast    1629.8335
# 1336   21  female    25.8         0     no  southwest     2007.945
# 1337   61  female   29.07         0     na  northwest   29141.3603
#
# [1334 rows x 7 columns]

# %%
d.isnull().sum()
# Out:
# age         0
# sex         1
# bmi         2
# children    0
# smoker      0
# region      1
# charges     0
# dtype: int64

# %%
print(d['sex'].fillna(method='bfill'))
# Out:
# 0       female
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 1333      male
# 1334    female
# 1335    female
# 1336    female
# 1337    female
# Name: sex, Length: 1338, dtype: object

# %%
print(d['region'].fillna(method='bfill'))
# Out:
# 0       southwest
# 1       southeast
# 2       southeast
# 3       northwest
# 4       northwest
#           ...
# 1333    northwest
# 1334    northeast
# 1335    southeast
# 1336    southwest
# 1337    northwest
# Name: region, Length: 1338, dtype: object

# %%
print(d)
d.interpolate()
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female    27.9         0    yes  southwest    16884.924
# 1      18    male   33.77         1     no  southeast    1725.5523
# 2      28    male      33         3     no  southeast     4449.462
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male   28.88         0     no  northwest    3866.8552
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male   30.97         3     no  northwest   10600.5483
# 1334   18  female   31.92         0     no  northeast    2205.9808
# 1335   18  female   36.85         0     no  southeast    1629.8335
# 1336   21  female    25.8         0     no  southwest     2007.945
# 1337   61  female   29.07         0     na  northwest   29141.3603
#
# [1338 rows x 7 columns]
#       age     sex     bmi  children smoker     region      charges
# 0      19  female    27.9         0    yes  southwest    16884.924
# ...

# %%
d.replace('[A-Za-z]','',regex=True)
# Out:
#       age sex     bmi  children smoker region      charges
# 0      19        27.9         0                  16884.924
# 1      18       33.77         1                  1725.5523
# 2      28          33         3                   4449.462
# 3      33      22.705         0                21984.47061
# 4      32       28.88         0                  3866.8552
# ...   ...  ..     ...       ...    ...    ...          ...
# 1333   50       30.97         3                 10600.5483
# 1334   18       31.92         0                  2205.9808
# 1335   18       36.85         0                  1629.8335
# 1336   21        25.8         0                   2007.945
# 1337   61       29.07         0                 29141.3603
#
# [1338 rows x 7 columns]

# %%
d.describe()
# Out:
#                age     children
# count  1338.000000  1338.000000
# mean     39.207025     1.094918
# std      14.049960     1.205493
# min      18.000000     0.000000
# 25%      27.000000     0.000000
# 50%      39.000000     1.000000
# 75%      51.000000     2.000000
# max      64.000000     5.000000

# %%
d['bmi'].fillna('bmi')
#d['sex'].fillna(0)
#d['region'].fillna(0)
# Out:
# 0         27.9
# 1        33.77
# 2           33
# 3       22.705
# 4        28.88
#          ...
# 1333     30.97
# 1334     31.92
# 1335     36.85
# 1336      25.8
# 1337     29.07
# Name: bmi, Length: 1338, dtype: object

# %%
d.replace(['no','yes'],[0,1])
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female    27.9         0      1  southwest    16884.924
# 1      18    male   33.77         1      0  southeast    1725.5523
# 2      28    male      33         3      0  southeast     4449.462
# 3      33    male  22.705         0      0  northwest  21984.47061
# 4      32    male   28.88         0      0  northwest    3866.8552
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male   30.97         3      0  northwest   10600.5483
# 1334   18  female   31.92         0      0  northeast    2205.9808
# 1335   18  female   36.85         0      0  southeast    1629.8335
# 1336   21  female    25.8         0      0  southwest     2007.945
# 1337   61  female   29.07         0     na  northwest   29141.3603
#
# [1338 rows x 7 columns]

# %%
d.notnull()
# Out:
#        age   sex   bmi  children  smoker  region  charges
# 0     True  True  True      True    True    True     True
# 1     True  True  True      True    True    True     True
# 2     True  True  True      True    True    True     True
# 3     True  True  True      True    True    True     True
# 4     True  True  True      True    True    True     True
# ...    ...   ...   ...       ...     ...     ...      ...
# 1333  True  True  True      True    True    True     True
# 1334  True  True  True      True    True    True     True
# 1335  True  True  True      True    True    True     True
# 1336  True  True  True      True    True    True     True
# 1337  True  True  True      True    True    True     True
#
# [1338 rows x 7 columns]

# %%
d.stack()
# Out:
# 0     age                 19
#       sex             female
#       bmi               27.9
#       children             0
#       smoker             yes
#                      ...
# 1337  bmi              29.07
#       children             0
#       smoker              na
#       region       northwest
#       charges     29141.3603
# Length: 9362, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
a=d.fillna(method='bfill',limit=1) 
print (a)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female    27.9         0    yes  southwest    16884.924
# 1      18    male   33.77         1     no  southeast    1725.5523
# 2      28    male      33         3     no  southeast     4449.462
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male   28.88         0     no  northwest    3866.8552
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male   30.97         3     no  northwest   10600.5483
# 1334   18  female   31.92         0     no  northeast    2205.9808
# 1335   18  female   36.85         0     no  southeast    1629.8335
# 1336   21  female    25.8         0     no  southwest     2007.945
# 1337   61  female   29.07         0     na  northwest   29141.3603
#
# [1338 rows x 7 columns]

# %%
a.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
import seaborn as sns

sns.countplot(x='sex',hue='bmi',data=a)
